# %%
import pandas as pd
# 设置pd显示时不换行
pd.set_option('display.width', 5000)
data = pd.read_csv("data/fish.csv")
data.head(3)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Species</th>
#       <th>Area</th>
#       <th>Weight</th>
#       <th>Length1</th>
#       <th>Length2</th>
#       <th>Length3</th>
#       <th>Height</th>
#       <th>Width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Bream</td>
#       <td>AF</td>
#       <td>242.0</td>
#       <td>23.2</td>
#       <td>25.4</td>
#       <td>30.0</td>
#       <td>11.5200</td>
#       <td>4.0200</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Bream</td>
#       <td>NY</td>
#       <td>290.0</td>
#       <td>24.0</td>
#       <td>26.3</td>
#       <td>31.2</td>
#       <td>12.4800</td>
#       <td>4.3056</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Bream</td>
#       <td>AS</td>
#       <td>340.0</td>
#       <td>23.9</td>
#       <td>26.5</td>
#       <td>31.1</td>
#       <td>12.3778</td>
#       <td>4.6961</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## 1. 数据过滤
# #### 1.1 单个条件过滤

# %%
filt = data["Length1"] > 25
data[filt].head(3)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Species</th>
#       <th>Area</th>
#       <th>Weight</th>
#       <th>Length1</th>
#       <th>Length2</th>
#       <th>Length3</th>
#       <th>Height</th>
#       <th>Width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>Bream</td>
#       <td>AS</td>
#       <td>363.0</td>
#       <td>26.3</td>
#       <td>29.0</td>
#       <td>33.5</td>
#       <td>12.7300</td>
#       <td>4.4555</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Bream</td>
#       <td>AF</td>
#       <td>430.0</td>
#       <td>26.5</td>
#       <td>29.0</td>
#       <td>34.0</td>
#       <td>12.4440</td>
#       <td>5.1340</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Bream</td>
#       <td>NY</td>
#       <td>450.0</td>
#       <td>26.8</td>
#       <td>29.7</td>
#       <td>34.7</td>
#       <td>13.6024</td>
#       <td>4.9274</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
filt = data["Species"] != "Bream"
data[filt].head(3)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Species</th>
#       <th>Area</th>
#       <th>Weight</th>
#       <th>Length1</th>
#       <th>Length2</th>
#       <th>Length3</th>
#       <th>Height</th>
#       <th>Width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>35</th>
#       <td>Roach</td>
#       <td>AF</td>
#       <td>40.0</td>
#       <td>12.9</td>
#       <td>14.1</td>
#       <td>16.2</td>
#       <td>4.1472</td>
#       <td>2.2680</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>Roach</td>
#       <td>AS</td>
#       <td>69.0</td>
#       <td>16.5</td>
#       <td>18.2</td>
#       <td>20.3</td>
#       <td>5.2983</td>
#       <td>2.8217</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>Roach</td>
#       <td>SA</td>
#       <td>78.0</td>
#       <td>17.5</td>
#       <td>18.8</td>
#       <td>21.2</td>
#       <td>5.5756</td>
#       <td>2.9044</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### 1.2 多个条件过滤

# %%
filt1 = data["Species"] !="Bream"
filt2 = data["Width"] > 5
data[filt1 & filt2].head(3)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Species</th>
#       <th>Area</th>
#       <th>Weight</th>
#       <th>Length1</th>
#       <th>Length2</th>
#       <th>Length3</th>
#       <th>Height</th>
#       <th>Width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>54</th>
#       <td>Roach</td>
#       <td>EN</td>
#       <td>390.0</td>
#       <td>29.5</td>
#       <td>31.7</td>
#       <td>35.0</td>
#       <td>9.4850</td>
#       <td>5.3550</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>Whitefish</td>
#       <td>EN</td>
#       <td>540.0</td>
#       <td>28.5</td>
#       <td>31.0</td>
#       <td>34.0</td>
#       <td>10.7440</td>
#       <td>6.5620</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>Whitefish</td>
#       <td>EN</td>
#       <td>800.0</td>
#       <td>33.7</td>
#       <td>36.4</td>
#       <td>39.6</td>
#       <td>11.7612</td>
#       <td>6.5736</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
data[filt1 | filt2].head(3)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Species</th>
#       <th>Area</th>
#       <th>Weight</th>
#       <th>Length1</th>
#       <th>Length2</th>
#       <th>Length3</th>
#       <th>Height</th>
#       <th>Width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4</th>
#       <td>Bream</td>
#       <td>AF</td>
#       <td>430.0</td>
#       <td>26.5</td>
#       <td>29.0</td>
#       <td>34.0</td>
#       <td>12.4440</td>
#       <td>5.1340</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Bream</td>
#       <td>SA</td>
#       <td>500.0</td>
#       <td>26.8</td>
#       <td>29.7</td>
#       <td>34.5</td>
#       <td>14.1795</td>
#       <td>5.2785</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Bream</td>
#       <td>AN</td>
#       <td>475.0</td>
#       <td>28.4</td>
#       <td>31.0</td>
#       <td>36.2</td>
#       <td>14.2628</td>
#       <td>5.1042</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### 1.3 通过query方式过滤
# 代码更可读

# %%
data.query("Length1>25").head(3)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Species</th>
#       <th>Area</th>
#       <th>Weight</th>
#       <th>Length1</th>
#       <th>Length2</th>
#       <th>Length3</th>
#       <th>Height</th>
#       <th>Width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>Bream</td>
#       <td>AS</td>
#       <td>363.0</td>
#       <td>26.3</td>
#       <td>29.0</td>
#       <td>33.5</td>
#       <td>12.7300</td>
#       <td>4.4555</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Bream</td>
#       <td>AF</td>
#       <td>430.0</td>
#       <td>26.5</td>
#       <td>29.0</td>
#       <td>34.0</td>
#       <td>12.4440</td>
#       <td>5.1340</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Bream</td>
#       <td>NY</td>
#       <td>450.0</td>
#       <td>26.8</td>
#       <td>29.7</td>
#       <td>34.7</td>
#       <td>13.6024</td>
#       <td>4.9274</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
data.query("Species!='Bream'").head(3)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Species</th>
#       <th>Area</th>
#       <th>Weight</th>
#       <th>Length1</th>
#       <th>Length2</th>
#       <th>Length3</th>
#       <th>Height</th>
#       <th>Width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>35</th>
#       <td>Roach</td>
#       <td>AF</td>
#       <td>40.0</td>
#       <td>12.9</td>
#       <td>14.1</td>
#       <td>16.2</td>
#       <td>4.1472</td>
#       <td>2.2680</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>Roach</td>
#       <td>AS</td>
#       <td>69.0</td>
#       <td>16.5</td>
#       <td>18.2</td>
#       <td>20.3</td>
#       <td>5.2983</td>
#       <td>2.8217</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>Roach</td>
#       <td>SA</td>
#       <td>78.0</td>
#       <td>17.5</td>
#       <td>18.8</td>
#       <td>21.2</td>
#       <td>5.5756</td>
#       <td>2.9044</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
data.query("Species!='Bream' and Width>5").head(3)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Species</th>
#       <th>Area</th>
#       <th>Weight</th>
#       <th>Length1</th>
#       <th>Length2</th>
#       <th>Length3</th>
#       <th>Height</th>
#       <th>Width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>54</th>
#       <td>Roach</td>
#       <td>EN</td>
#       <td>390.0</td>
#       <td>29.5</td>
#       <td>31.7</td>
#       <td>35.0</td>
#       <td>9.4850</td>
#       <td>5.3550</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>Whitefish</td>
#       <td>EN</td>
#       <td>540.0</td>
#       <td>28.5</td>
#       <td>31.0</td>
#       <td>34.0</td>
#       <td>10.7440</td>
#       <td>6.5620</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>Whitefish</td>
#       <td>EN</td>
#       <td>800.0</td>
#       <td>33.7</td>
#       <td>36.4</td>
#       <td>39.6</td>
#       <td>11.7612</td>
#       <td>6.5736</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
data.query("Species!='Bream' or Width>5").head(3)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Species</th>
#       <th>Area</th>
#       <th>Weight</th>
#       <th>Length1</th>
#       <th>Length2</th>
#       <th>Length3</th>
#       <th>Height</th>
#       <th>Width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4</th>
#       <td>Bream</td>
#       <td>AF</td>
#       <td>430.0</td>
#       <td>26.5</td>
#       <td>29.0</td>
#       <td>34.0</td>
#       <td>12.4440</td>
#       <td>5.1340</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Bream</td>
#       <td>SA</td>
#       <td>500.0</td>
#       <td>26.8</td>
#       <td>29.7</td>
#       <td>34.5</td>
#       <td>14.1795</td>
#       <td>5.2785</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Bream</td>
#       <td>AN</td>
#       <td>475.0</td>
#       <td>28.4</td>
#       <td>31.0</td>
#       <td>36.2</td>
#       <td>14.2628</td>
#       <td>5.1042</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ##2. Aggregating 方法
# 聚合： 针对有一个数值类型的列进行 包括 **sum**, **mean**, **median**,**max**,**min**等

# %%
# # 求Weight列到Width列的每一列的平均值
data_num = data.loc[:, 'Weight':'Width']
data_num.mean()
# data_num.median()
# data_num.sum()
# data_num.max()
# data_num.min()
# Out:
# Weight     398.326415
# Length1     26.247170
# Length2     28.415723
# Length3     31.227044
# Height       8.970994
# Width        4.417486
# dtype: float64

# %%
# #对某一列进行聚合
data.loc[:, 'Weight'].sum()
# data.loc[:,'Weight'].sum(axis=0)
# Out:
# 63333.9

# %%
# 按行进行聚合
data_num.sum(axis=1)
# Out:
# 0       336.1400
# 1       388.2856
# 2       438.5739
# 3       468.9855
# 4       537.0780
# 5       559.7298
# 6       610.4580
# 7       499.9600
# 8       561.5487
# 9       614.5860
# 10      589.9670
# 11      615.0860
# 12      615.1272
# 13      457.7857
# 14      718.7252
# 15      719.6180
# 16      821.8458
# 17      822.0355
# 18      733.7668
# 19      773.4014
# 20      700.4980
# 21      810.9640
# 22      746.5028
# 23      808.9992
# 24      829.2295
# 25      855.1132
# 26      850.0518
# 27      846.5685
# 28      983.4880
# 29     1138.6600
#          ...
# 129     413.3658
# 130     416.8208
# 131     422.2082
# 132     555.8665
# 133     470.8730
# 134     595.6025
# 135     649.2840
# 136     681.8156
# 137     646.8560
# 138     717.5620
# 139     927.0560
# 140    1120.1974
# 141    1435.3712
# 142    1795.7440
# 143    1745.7440
# 144    1858.6920
# 145      39.3864
# 146      42.7320
# 147      42.1768
# 148      46.6760
# 149      47.4604
# 150      46.6634
# 151      49.6977
# 152      49.4798
# 153      49.7528
# 154      52.7840
# 155      54.6990
# 156      54.6328
# 157      67.3400
# 158      69.7114
# Length: 159, dtype: float64

# %% [markdown]
# ##3. 非Aggregating方法
# round(n): 取小数点后n位

# %%
data_num.round(2).head(3)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Weight</th>
#       <th>Length1</th>
#       <th>Length2</th>
#       <th>Length3</th>
#       <th>Height</th>
#       <th>Width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>242.0</td>
#       <td>23.2</td>
#       <td>25.4</td>
#       <td>30.0</td>
#       <td>11.52</td>
#       <td>4.02</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>290.0</td>
#       <td>24.0</td>
#       <td>26.3</td>
#       <td>31.2</td>
#       <td>12.48</td>
#       <td>4.31</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>340.0</td>
#       <td>23.9</td>
#       <td>26.5</td>
#       <td>31.1</td>
#       <td>12.38</td>
#       <td>4.70</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ##4. Aggregating with groups
# ####4.1 统计某一列每一个取值的频次

# %%
# #统计Species中每个类型的个数
data['Species'].value_counts()
# Out:
# Perch        56
# Bream        35
# Roach        20
# Pike         17
# Smelt        14
# Parkki       11
# Whitefish     6
# Name: Species, dtype: int64

# %% [markdown]
# ####4.2 单列聚合，单个聚合函数

# %%
# #统计每种species的Height的平均值
data.groupby("Species")["Height"].agg([("height_mean", "mean")])
# #or
# data.groupby("Species").agg({"Height": [("height_mean", "mean")]})
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>height_mean</th>
#     </tr>
#     <tr>
#       <th>Species</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Bream</th>
#       <td>15.183211</td>
#     </tr>
#     <tr>
#       <th>Parkki</th>
#       <td>8.962427</td>
#     </tr>
#     <tr>
#       <th>Perch</th>
#       <td>7.861870</td>
#     </tr>
#     <tr>
#       <th>Pike</th>
#       <td>7.713771</td>
#     </tr>
#     <tr>
#       <th>Roach</th>
#       <td>6.694795</td>
#     </tr>
#     <tr>
#       <th>Smelt</th>
#       <td>2.209371</td>
#     </tr>
#     <tr>
#       <th>Whitefish</th>
#       <td>10.027167</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ####4.3 单列聚合，多个聚合函数

# %%
# # 统计每种species的Height的平均值，最大值，总数
# # or
# data.groupby("Species")["Height"].agg([("height_mean", "mean"), 
#                                        ("height_max", "max"), 
#                                        ("height_count", "count")])
data.groupby('Species').agg({"Height": [("height_mean", "mean"), 
                                        ("height_max", "max"), 
                                        ("height_count", "count")]})
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead tr th {
#         text-align: left;
#     }
#
#     .dataframe thead tr:last-of-type th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="3" halign="left">Height</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>height_mean</th>
#       <th>height_max</th>
#       <th>height_count</th>
#     </tr>
#     <tr>
#       <th>Species</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Bream</th>
#       <td>15.183211</td>
#       <td>18.9570</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>Parkki</th>
#       <td>8.962427</td>
#       <td>11.3680</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>Perch</th>
#       <td>7.861870</td>
#       <td>12.8002</td>
#       <td>56</td>
#     </tr>
#     <tr>
#       <th>Pike</th>
#       <td>7.713771</td>
#       <td>10.8120</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>Roach</th>
#       <td>6.694795</td>
#       <td>9.4850</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>Smelt</th>
#       <td>2.209371</td>
#       <td>2.9322</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>Whitefish</th>
#       <td>10.027167</td>
#       <td>12.3540</td>
#       <td>6</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ####4.4 按多个列进行聚合

# %%
data.groupby(['Species','Area']).agg({"Height": [("height_mean", "mean"), 
                                        ("height_max", "max"), 
                                        ("height_count", "count")]})
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead tr th {
#         text-align: left;
#     }
#
#     .dataframe thead tr:last-of-type th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th colspan="3" halign="left">Height</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>height_mean</th>
#       <th>height_max</th>
#       <th>height_count</th>
#     </tr>
#     <tr>
#       <th>Species</th>
#       <th>Area</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="9" valign="top">Bream</th>
#       <th>AD</th>
#       <td>16.240500</td>
#       <td>16.2405</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>AF</th>
#       <td>15.000078</td>
#       <td>18.6354</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>AM</th>
#       <td>15.559360</td>
#       <td>17.6235</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>AN</th>
#       <td>14.262800</td>
#       <td>14.2628</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>AS</th>
#       <td>14.117050</td>
#       <td>16.3618</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>CH</th>
#       <td>17.611900</td>
#       <td>18.9570</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>EN</th>
#       <td>18.395550</td>
#       <td>18.7542</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>NY</th>
#       <td>13.615640</td>
#       <td>14.9544</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>SA</th>
#       <td>14.046200</td>
#       <td>14.1795</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">Parkki</th>
#       <th>AD</th>
#       <td>7.622980</td>
#       <td>8.8928</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>CH</th>
#       <td>10.078633</td>
#       <td>11.3680</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th rowspan="7" valign="top">Perch</th>
#       <th>AD</th>
#       <td>5.869533</td>
#       <td>6.7920</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>AK</th>
#       <td>5.740190</td>
#       <td>6.3840</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>AM</th>
#       <td>12.488800</td>
#       <td>12.4888</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>AS</th>
#       <td>4.152286</td>
#       <td>5.2224</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>EN</th>
#       <td>9.782120</td>
#       <td>12.4313</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>NY</th>
#       <td>6.926122</td>
#       <td>8.3230</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>SA</th>
#       <td>12.127987</td>
#       <td>12.8002</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">Pike</th>
#       <th>AK</th>
#       <td>8.871389</td>
#       <td>10.8120</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>AM</th>
#       <td>6.411450</td>
#       <td>7.2900</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th rowspan="8" valign="top">Roach</th>
#       <th>AD</th>
#       <td>6.114600</td>
#       <td>6.1146</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>AF</th>
#       <td>6.998000</td>
#       <td>8.8768</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>AK</th>
#       <td>7.084150</td>
#       <td>7.5344</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>AS</th>
#       <td>6.171550</td>
#       <td>7.0334</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>CH</th>
#       <td>7.396800</td>
#       <td>7.3968</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>EN</th>
#       <td>7.086100</td>
#       <td>9.4850</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>NY</th>
#       <td>6.265950</td>
#       <td>6.9153</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>SA</th>
#       <td>5.575600</td>
#       <td>5.5756</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">Smelt</th>
#       <th>NY</th>
#       <td>2.467800</td>
#       <td>2.9322</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>SA</th>
#       <td>2.015550</td>
#       <td>2.2139</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">Whitefish</th>
#       <th>AD</th>
#       <td>12.354000</td>
#       <td>12.3540</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>EN</th>
#       <td>9.561800</td>
#       <td>11.7612</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ####4.5 构建透视表

# %%
pt = data.pivot_table(index="Species",columns="Area",values="Height",aggfunc="mean")
pt
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Area</th>
#       <th>AD</th>
#       <th>AF</th>
#       <th>AK</th>
#       <th>AM</th>
#       <th>AN</th>
#       <th>AS</th>
#       <th>CH</th>
#       <th>EN</th>
#       <th>NY</th>
#       <th>SA</th>
#     </tr>
#     <tr>
#       <th>Species</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Bream</th>
#       <td>16.240500</td>
#       <td>15.000078</td>
#       <td>NaN</td>
#       <td>15.55936</td>
#       <td>14.2628</td>
#       <td>14.117050</td>
#       <td>17.611900</td>
#       <td>18.39555</td>
#       <td>13.615640</td>
#       <td>14.046200</td>
#     </tr>
#     <tr>
#       <th>Parkki</th>
#       <td>7.622980</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>10.078633</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Perch</th>
#       <td>5.869533</td>
#       <td>NaN</td>
#       <td>5.740190</td>
#       <td>12.48880</td>
#       <td>NaN</td>
#       <td>4.152286</td>
#       <td>NaN</td>
#       <td>9.78212</td>
#       <td>6.926122</td>
#       <td>12.127987</td>
#     </tr>
#     <tr>
#       <th>Pike</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>8.871389</td>
#       <td>6.41145</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Roach</th>
#       <td>6.114600</td>
#       <td>6.998000</td>
#       <td>7.084150</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>6.171550</td>
#       <td>7.396800</td>
#       <td>7.08610</td>
#       <td>6.265950</td>
#       <td>5.575600</td>
#     </tr>
#     <tr>
#       <th>Smelt</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>2.467800</td>
#       <td>2.015550</td>
#     </tr>
#     <tr>
#       <th>Whitefish</th>
#       <td>12.354000</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>9.56180</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ##5. styling Dataframe

# %%
s = data_num.style.highlight_max()
# #s是HTML输出，不能直接在pycharm控制台显示，需要在jupyter中显示
s.render()
# Out:
# '<style  type="text/css" >\n    #T_6d8b192a_a712_11ea_9674_049226bdf81crow29_col4 {\n            background-color:  yellow;\n        }    #T_6d8b192a_a712_11ea_9674_049226bdf81crow126_col5 {\n            background-color:  yellow;\n        }    #T_6d8b192a_a712_11ea_9674_049226bdf81crow144_col0 {\n            background-color:  yellow;\n        }    #T_6d8b192a_a712_11ea_9674_049226bdf81crow144_col1 {\n            background-color:  yellow;\n        }    #T_6d8b192a_a712_11ea_9674_049226bdf81crow144_col2 {\n            background-color:  yellow;\n        }    #T_6d8b192a_a712_11ea_9674_049226bdf81crow144_col3 {\n            background-color:  yellow;\n        }</style><table id="T_6d8b192a_a712_11ea_9674_049226bdf81c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Weight</th>        <th class="col_heading level0 col1" >Length1</th>        <th class="col_heading level0 col2" >Length2</th>        <th class="col_heading level0 col3" >Length3</th>        <th class="col_heading level0 col4" >Height</th>        <th class="col_heading level0 col5" >Width</th>    </tr></thead><tbody>\n                <tr>\n                        <th id="T_6d8b192a_a712_11ea_9674_049226bdf81clevel0_row0" class="row_heading level0 row0" >0</th>\n                        <td id="T_6d8b192a_a712_11ea_9674_049226bdf81crow0_col0" class="data row0 col0" >242</td>\n                        <td id="T_6d8b192a_a712_11ea_9674_049226bdf81crow0_col1" class="data row0 col1" >23.2</td>\n                        <td id="T_6d8b192a_a712_11ea_9674_049226bdf81crow0_col2" class="data row0 col2" >25.4</td>\n                        <td id="T_6d8b192a_a712_11ea_9674_049226bdf81crow0_col3" class="data row0 col3" >30</td>\n                        <td id="T_6d8b192a_a712_11ea_9674_049226bdf81crow0_col4" class="data row0 col4" >11.52</td>\n                        <td id="T_6d8b192a_a712_11ea_9674_049226bdf81crow0_col5" class="data row0 col5" >4.02</td>\n            </tr>\n            <tr>\n                        <th id="T_6d8b192a_a712_11ea_9674_049226bdf81clevel0_row1" class="row_heading level0 row1" >1</th>\n                        <td id="T_6d8b192a_a712_11ea_9674_049226bdf81crow1_col0" class="data row1 col0" >290</td>\n                        <td id="T_6d8b192a_a712_11ea_9674_049226bdf81crow1_col1" class="data row1 col1" >24</td>\n                        <td id="T_6d8b192a_a712_11ea_9674_049226bdf81crow1_col2" class="data row1 col2" >26.3</td>\n                        <td id="T_6d8b192a_a712_11ea_9674_049226bdf81crow1_col3" class="data row1 col3" >31.2</td>\n                        <td id="T_6d8b192a_a712_11ea_9674_049226bdf81crow1_col4" class="data row1 col4" >12.48</td>\n                        <td id="T_6d8b192a_a712_11ea_9674_049226bdf81crow1_col5" class="data row1 col5" >4.3056</td>\n            </tr>\n            <tr>\n                        <th id="T_6d8b192a_a712_11ea_9674_049226bdf81clevel0_row2" class="row_heading level0 row2" >2</th>\n                        <td id="T_6d8b192a_a712_11ea_9674_049226bdf81crow2_col0" class="data row2 col0" >340</td>\n                        <td id="T_6d8b192a_a712_11ea_9674_049226bdf81crow2_col1" class="data row2 col1" >23.9</td>\n                        <td id="T_6d8b192a_a712_11ea_9674_049226bdf81crow2_col2" class="data row2 col2" >26.5</td>\n                        <td id="T_6d8b192a_a712_11ea_9674_049226bdf81crow2_col3" class="data row2 col3" >31.1</td>\n                        <td id="T_6d8b192a_a712_11ea_9674_049226bdf81crow2_col4" class="data row2 col4" >12.3778</td>\n                        <td id="T_6d8b192a_a712_11ea_9674_049226bdf81crow2_col5" class="data row2 col5" >4.6961</td>\n            </tr>\n            <tr>\n                        <th id="T_6d8b192a_a712_11ea_9674_049226bdf81clevel0_row3" class="row_heading level0 row3" >3</th>\n                        <td id="T_6d8b192a_a712_11ea_9674_049226bdf81crow3_col0" class="data row3 col0" >363</td>\n                    ...
